# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# Read the image in grayscale
image_path = 'banana.png'  
image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
#Original image matrix
print(image)
# Out:
# [[61 61 60 ... 21 21 21]
#  [62 61 61 ... 19 19 19]
#  [62 62 61 ... 16 16 16]
#  ...
#  [51 52 54 ... 87 87 87]
#  [48 50 53 ... 86 86 86]
#  [46 49 53 ... 84 84 84]]

# %%
# Original image
plt.imshow(image, cmap='gray')
plt.title('Original Image')
plt.show()

# %%
# Transpose the matrix
transposed_image = np.transpose(image)
#Transponsed image matrix
print(transposed_image)
# Out:
# [[61 62 62 ... 51 48 46]
#  [61 61 62 ... 52 50 49]
#  [60 61 61 ... 54 53 53]
#  ...
#  [21 19 16 ... 87 86 84]
#  [21 19 16 ... 87 86 84]
#  [21 19 16 ... 87 86 84]]

# %%
# Display the transposed image
plt.imshow(transposed_image, cmap='gray')
plt.title('Transposed Image')
plt.show()

# %%
# Invert the pixel values matrix
inverted_image = 255 - image

print(inverted_image)
# Out:
# [[194 194 195 ... 234 234 234]
#  [193 194 194 ... 236 236 236]
#  [193 193 194 ... 239 239 239]
#  ...
#  [204 203 201 ... 168 168 168]
#  [207 205 202 ... 169 169 169]
#  [209 206 202 ... 171 171 171]]

# %%
# Display the inverted image
plt.imshow(inverted_image, cmap='gray')
plt.title('Inverted Image')
plt.show()
